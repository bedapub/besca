# %% [markdown]
# # Minimalal notebook to test convert_notebook_to_HTML()

# %%
import besca as bc
# Out:
# /home/hatjek/scratch/conda/envs/besca3/lib/python3.12/site-packages/umap/__init__.py:9: ImportWarning: Tensorflow not installed; ParametricUMAP will be unavailable
#   warn(

# %%
bc.print_software_versions()
# Out:
# /gpfs/scratchfs01/site/u/hatjek/devel/besca/besca/_helper.py:503: FutureWarning: `__version__` is deprecated, use `importlib.metadata.version('scanpy')` instead
#   scv = sc.__version__
# /gpfs/scratchfs01/site/u/hatjek/devel/besca/besca/_helper.py:504: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if StrictVersion(scv) >= "1.6":
# besca==3.0
# matplotlib==3.10.8
# /gpfs/scratchfs01/site/u/hatjek/devel/besca/besca/_helper.py:509: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   bcstr = StrictVersion(re.sub("\\+.*$", "", bcver))
# Versions(scanpy='1.12', besca='3.0.0')

# %%
bc.convert_notebook_to_HTML()
# Out:
# CompletedProcess(args=['jupyter', 'nbconvert', '--to', 'html', '/gpfs/scratchfs01/site/u/hatjek/devel/besca/workbooks/standard_workflow_besca2.ipynb'], returncode=0, stdout=b'', stderr=b'[NbConvertApp] Converting notebook /gpfs/scratchfs01/site/u/hatjek/devel/besca/workbooks/standard_workflow_besca2.ipynb to html\n[NbConvertApp] Writing 406078 bytes to /gpfs/scratchfs01/site/u/hatjek/devel/besca/workbooks/standard_workflow_besca2.html\n')
